# %%
import requests
from duckduckgo_search import DDGS
from time import sleep
import pandas as pd
from pydantic import BaseModel, ValidationError
from time import time

# %%
def search_news_by_keywords(keyword, persona_name, max_results=10000):
    search_term = keyword 
    with DDGS() as ddgs:
        results = ddgs.news(
            keywords=search_term,
            region="es-es",
            safesearch="Moderate",
            timelimit="w",
            max_results=max_results
        )
        return [{"persona": persona_name, "query": search_term, **r} for r in results]

# %%
persona_keywords = {
    "Laura Gil": [
        "inteligencia artificial", "datos", "transformación digital",
        "industria 4.0", "automatización", "cultura de innovación"
    ],
    "Fede Segarra": [
        "comunicación corporativa", "reputación de marca", "PR", 
        "estrategias de comunicación", "imagen pública"
    ],
    "Elísabeth Hernández": [
        "recursos humanos", "RSC", "desarrollo del talento", 
        "formación corporativa", "comunicación interna", "voluntariado"
    ],
    "Jaume Alemany": [
        "marketing", "branding", "consumo", "bebidas", 
        "innovación de producto", "campañas publicitarias"
    ],
    "Ricardo Lechuga": [
        "transformación cultural", "talento interno", "digitalización RRHH", 
        "engagement de empleados", "liderazgo cercano"
    ],
    "Jorge Villavecchia": [
        "liderazgo empresarial", "estrategia corporativa", "sostenibilidad", 
        "transformación de negocios", "expansión internacional"
    ],
    "Salvador Martínez": [
        "finanzas sostenibles", "crecimiento responsable", 
        "decisiones basadas en datos", "ética empresarial"
    ],
    "Jofre Riera": [
        "patrocinios deportivos", "marketing cultural", 
        "experiencias de marca", "impacto social"
    ]
}

# %%
all_results = []
for persona, keywords in persona_keywords.items():
    keyword_results = []
    for keyword in keywords:
        results = search_news_by_keywords(keyword, persona)
        keyword_results.extend(results)
        print(f"Results for {persona} on '{keyword}': {len(results)} found.")
        print(f"Sleeping for 20 seconds to avoid rate limiting...")
        sleep(20)
        break 
        
    all_results.extend(keyword_results)
# Out:
# Results for Laura Gil on 'inteligencia artificial': 52 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Fede Segarra on 'comunicación corporativa': 26 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Elísabeth Hernández on 'recursos humanos': 57 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Jaume Alemany on 'marketing': 83 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Ricardo Lechuga on 'transformación cultural': 35 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Jorge Villavecchia on 'liderazgo empresarial': 47 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Salvador Martínez on 'finanzas sostenibles': 32 found.
# Sleeping for 20 seconds to avoid rate limiting...
# Results for Jofre Riera on 'patrocinios deportivos': 30 found.
# Sleeping for 20 seconds to avoid rate limiting...

# %%
df_results = pd.DataFrame(all_results)
df_results.head()
# Out:
#      persona                    query                       date  \
# 0  Laura Gil  inteligencia artificial  2025-06-20T11:39:00+00:00
# 1  Laura Gil  inteligencia artificial  2025-06-20T11:42:00+00:00
# 2  Laura Gil  inteligencia artificial  2025-06-20T08:13:00+00:00
# 3  Laura Gil  inteligencia artificial  2025-06-20T12:55:13+00:00
# 4  Laura Gil  inteligencia artificial  2025-06-20T13:16:00+00:00
#
#                                                title  \
# 0  León XIV quiere una inteligencia artificial qu...
# 1  Esta es la ciudad de España donde viven las pe...
# 2  El español impulsa la inteligencia artificial ...
# 3  El Teatro Mariinski estrena la primera ópera c...
# 4                 Inteligencia Artificial En Espanol
#
#                                                 body  \
# 0  Desde ayer hasta hoy, 20 de junio, Roma está a...
# 1  Esta tecnología indica que no existe en España...
# 2  Proyectos innovadores, startups y colaboración...
# 3  El estreno de la obra ha sido el suceso cultur...
# 4  El sitio de noticias en español más leído en e...
#
#                                                  url  \
# 0  https://www.vidanuevadigital.com/2025/06/20/le...
# 1  https://www.abc.es/recreo/ciudad-espana-viven-...
# 2  https://www.infobae.com/tecno/2025/06/20/el-es...
# 3  https://www.msn.com/es-es/entretenimiento/musi...
# 4  https://www.infobae.com/tag/inteligencia-artif...
#
#                                                image      source
# 0  https://www.vidanuevadigital.com/wp-content/up...  Vida Nueva
# 1  https://s1.abcstatics.com/abc/www/multimedia/r...         ABC
# 2  https://www.infobae.com/resizer/v2/OPPFAUUDPNF...     Infobae
# 3  https://fotografias.larazon.es/clipping/cmsima...    La Razón
# 4  https://www.infobae.com/pf/resources/images/fa...     Infobae

# %%
len(df_results)
# Out:
# 362

# %%
class RawArticle(BaseModel):
    run_id: str
    source_name: str
    source_url: str
    article_id: str
    article_date: str
    article_title: str
    article_url: str
    article_body: str
    article_image_url: str
    article_language: str
    crawled_at: str
    ddgs_search_query: str
    query_original_personas: list[str]

# %%
runid = "DEVRUN"

# %%
df_results = pd.DataFrame(all_results)
df_results.head()

agg_clause = {col : 'first' for col in df_results.columns}
agg_clause.pop('url')
agg_clause['persona'] = lambda x: list(x)
agg_clause['query'] = lambda x: list(x)
df_results = df_results.groupby('url').agg(agg_clause).reset_index()

df_results["source_url"] = df_results["url"].apply(lambda x: "/".join(x.split("/")[:3]) if pd.notna(x) else None)
df_results["source"] = df_results["source"].apply(lambda x: x.replace(" ", "_").lower() if pd.notna(x) else None)
df_results["article_id"] = df_results["source"].apply(lambda x: x + "_" + str(time()).replace(".", "") if pd.notna(x) else None)
df_results.dropna(subset=["source_url", "source", "article_id"], inplace=True)
df_results["crawled_at"] = pd.to_datetime("now").isoformat()
df_results["article_language"] = "es"  
df_results["run_id"] = runid

df_results.rename(columns={
    "title": "article_title",
    "url": "article_url",
    "body": "article_body",
    "image": "article_image_url",
    "source": "source_name",
    "query": "ddgs_search_query",
    "persona": "query_original_personas",
    "date" : "article_date"
}, inplace=True)

df_results.head()
# Out:
#                                          article_url  \
# 0  https://abcnoticias.mx/local/2025/6/19/asegura...
# 1  https://acento.com.do/opinion/americo-lugo-con...
# 2  https://amprensa.com/2025/06/una-cerveza-en-la...
# 3  https://blogs.elconfidencial.com/economia/trib...
# 4  https://blogs.elconfidencial.com/mercados/el-a...
#
#               query_original_personas  \
# 0                [Jorge Villavecchia]
# 1                   [Ricardo Lechuga]
# 2                       [Jofre Riera]
# 3  [Fede Segarra, Jorge Villavecchia]
# 4                [Jorge Villavecchia]
#
#                                    ddgs_search_query  \
# 0                            [liderazgo empresarial]
# 1                          [transformación cultural]
# 2                           [patrocinios deportivos]
# 3  [comunicación corporativa, liderazgo empresarial]
# 4                            [liderazgo empresarial]
#
#                 article_date  \
# 0  2025-06-20T05:24:00+00:00
# 1  2025-06-19T04:03:00+00:00
# 2  2025-06-14T13:19:00+00:00
# 3  2025-06-15T03:00:00+00:00
# 4  2025-06-20T03:00:00+00:00
#
#                                        article_title  \
# 0  Asegura Estado que en NL hay 3 millones de tra...
# 1                 Américo Lugo, conciencia de nación
# 2  Una cerveza en la cancha: Michelob se suma al ...
# 3  El nuevo liderazgo empresarial se mide en inta...
# 4  Tu decisión más importante: quién construye a ...
#
#                                         article_body  \
# 0  El estado cuenta con una Población Económicame...
# 1  La democracia dominicana no alcanza su mayor e...
# 2  -La marca fortalece su vínculo con el deporte ...
# 3  Vivimos en un contexto marcado por la volatili...
# 4  El último informe del World Economic Forum rev...
#
#                                    article_image_url  \
# 0  https://abcnoticias.mx/u/fotografias/m/2025/6/...
# 1  https://media.acento.com.do/media/storage02/up...
# 2  https://cdn.amprensa.com/785ac538-0f24-40f0-8e...
# 3  https://images.ecestaticos.com/9RnhwFbvwGgFK-w...
# 4  https://images.ecestaticos.com/lI9rSLCtTt6IrCq...
#
#                 source_name                        source_url  \
# 0              abc_noticias            https://abcnoticias.mx
# 1                    acento             https://acento.com.do
# 2              amprensa.com              https://amprensa.com
# 3  blogs_en_el_confidencial  https://blogs.elconfidencial.com
# 4  blogs_en_el_confidencial  https://blogs.elconfidencial.com
#
#                                    article_id                  crawled_at  \
# 0              abc_noticias_17504333710091262  2025-06-20T17:29:31.010764
# 1                    acento_17504333710091338  2025-06-20T17:29:31.010764
# 2              amprensa.com_17504333710091372  2025-06-20T17:29:31.010764
# 3  blogs_en_el_confidencial_17504333710091393  2025-06-20T17:29:31.010764
# 4   blogs_en_el_confidencial_1750433371009141  2025-06-20T17:29:31.010764
#
#   article_language  run_id
# 0               es  DEVRUN
# 1               es  DEVRUN
# 2               es  DEVRUN
# 3               es  DEVRUN
# 4               es  DEVRUN

# %%
# convert to RawArticle model
raw_articles = []
for _, row in df_results.iterrows():
    try:
        article = RawArticle(
            run_id=row["run_id"],
            source_name=row["source_name"],
            source_url=row["source_url"],
            article_id=row["article_id"],
            article_date=row["article_date"],
            article_title=row["article_title"],
            article_url=row["article_url"],
            article_body=row["article_body"],
            article_image_url=row["article_image_url"],
            article_language=row["article_language"],
            crawled_at=row["crawled_at"],
            ddgs_search_query=row["ddgs_search_query"],
            query_original_personas=row["query_original_personas"]
        )
        raw_articles.append(article)
    except ValidationError as e:
        print(f"Validation error for row {row['article_id']}: {e}")

# %%
raw_articles
# Out:
# [RawArticle(run_id='DEVRUN', source_name='abc_noticias', source_url='https://abcnoticias.mx', article_id='abc_noticias_17504326268107831', article_date='2025-06-20T05:24:00+00:00', article_title='Asegura Estado que en NL hay 3 millones de trabajadores formales', article_url='https://abcnoticias.mx/local/2025/6/19/asegura-estado-que-en-nl-hay-millones-de-trabajadores-formales-252475.html', article_body='El estado cuenta con una Población Económicamente Activa cercana a los 3 millones de personas, con una tasa de desempleo de apenas 2.8% y una informalidad laboral del 32.5%, la más baja del país, lo que se traduce en mayor acceso a seguridad social, prestaciones laborales y estabilidad económica para los trabajadores.', article_image_url='https://abcnoticias.mx/u/fotografias/m/2025/6/19/f1280x720-302753_434428_5050.png', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='acento', source_url='https://acento.com.do', article_id='acento_17504326268107882', article_date='2025-06-19T04:03:00+00:00', article_title='Américo Lugo, conciencia de nación', article_url='https://acento.com.do/opinion/americo-lugo-conciencia-de-nacion-9512801.html', article_body='La democracia dominicana no alcanza su mayor esplendor por un defecto técnico, sino por una insuficiencia moral. Y esa insuficiencia tiene raíces profundas en nuestra historia colonial, en la larga so', article_image_url='https://media.acento.com.do/media/storage02/uploads/2021/11/captura-de-pantalla-2021-11-09-a-las-101838-am.png', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='transformación cultural', query_original_personas=['Ricardo Lechuga']),
#  RawArticle(run_id='DEVRUN', source_name='amprensa.com', source_url='https://amprensa.com', article_id='amprensa.com_17504326268107898', article_date='2025-06-14T13:19:00+00:00', article_title='Una cerveza en la cancha: Michelob se suma al Mundial de Clubes como aliada del fútbol', article_url='https://amprensa.com/2025/06/una-cerveza-en-la-cancha-michelob-se-suma-al-mundial-de-clubes-como-aliada-del-futbol', article_body='-La marca fortalece su vínculo con el deporte internacional y apunta a conectar con la afición costarricense desde la experiencia del juego. Michelob, reconocida por su perfil ligero y su enfoque en u', article_image_url='https://cdn.amprensa.com/785ac538-0f24-40f0-8e92-78417e9b7fb3', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
#  RawArticle(run_id='DEVRUN', source_name='blogs_en_el_confidencial', source_url='https://blogs.elconfidencial.com', article_id='blogs_en_el_confidencial_17504326268107905', article_date='2025-06-15T03:00:00+00:00', article_title='El nuevo liderazgo empresarial se mide en intangibles', article_url='https://blogs.elconfidencial.com/economia/tribuna/2025-06-15/reputacion-inteligencia-artificial-gestion-1hms_4151339/', article_body='Vivimos en un contexto marcado por la volatilidad, la polarización y la aceleración tecnológica. Las empresas se enfrentan a una creciente presión para anticiparse, actuar con legitimidad y generar va', article_image_url='https://images.ecestaticos.com/9RnhwFbvwGgFK-wDBolD8QWwJOA=/0x0:1254x837/600x315/filters:fill(white):format(jpg):quality(99):watermark(f.elconfidencial.com/file/bae/eea/fde/baeeeafde1b3229287b0c008f7602058.png,0,275,1)/f.elconfidencial.com/original/c17/2c6/2c9/c172c62c9a82d37f9d41774a063b52c3.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra', 'Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='blogs_en_el_confidencial', source_url='https://blogs.elconfidencial.com', article_id='blogs_en_el_confidencial_17504326268107915', article_date='2025-06-20T03:00:00+00:00', article_title='Tu decisión más importante: quién construye a tu lado', article_url='https://blogs.elconfidencial.com/mercados/el-arte-de-crear/2025-06-20/brecha-genero-liderazgo-mujeres-1hms_4155099/', article_body='El último informe del World Economic Forum revela que la igualdad de género global no se alcanzará hasta 2148, subrayando la urgencia de elegir bien con quién construimos nuestro futuro', article_image_url='https://images.ecestaticos.com/lI9rSLCtTt6IrCqneuom56_Jy94=/0x0:2121x1414/600x315/filters:fill(white):format(jpg):quality(99):watermark(f.elconfidencial.com/file/bae/eea/fde/baeeeafde1b3229287b0c008f7602058.png,0,275,1)/f.elconfidencial.com/original/263/b06/e83/263b06e830258f66ea7e786f791a6b11.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='cadena_ser', source_url='https://cadenaser.com', article_id='cadena_ser_17504326268107922', article_date='2025-06-19T18:55:00+00:00', article_title='Natichu Alvarado: "Todavía no sabemos cuál es nuestro límite salarial"', article_url='https://cadenaser.com/castillayleon/2025/06/19/natichu-alvarado-todavia-no-sabemos-cual-es-nuestro-limite-salarial-radio-leon/', article_body='"Pero tenemos algún fichaje avanzado" explica la consejera ejecutiva de la Cultural que espera las nuevas camisetas y la campaña de abonados para primeros de julio con "precios asequibles" | Cadena SE', article_image_url='https://cadenaser.com/resizer/v2/X2ZVIS5PKRCPJHS5BZTJE7DBSE.jpeg?auth=7e75d653079e676d2e7b9a28dd3af431b0679c7f3f3d2ca959a409421cda9b72&quality=70&width=1200&height=675&smart=true', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
#  RawArticle(run_id='DEVRUN', source_name='cadena_ser', source_url='https://cadenaser.com', article_id='cadena_ser_1750432626810793', article_date='2025-06-19T06:11:00+00:00', article_title='PSOE Tres Cantos pide fomentar que el tejido empresarial local patrocine a los clubes deportivos', article_url='https://cadenaser.com/cmadrid/2025/06/19/psoe-tres-cantos-pide-fomentar-que-el-tejido-empresarial-local-patrocine-a-los-clubes-deportivos-ser-madrid-norte/', article_body="Ha presentado una moción al Pleno que propone también la celebración de 'La noche del Deporte de Tres Cantos' | Cadena SER", article_image_url='https://cadenaser.com/resizer/v2/ZMCFWHPFEFKAFN4J22ZDG4C7FU.jpg?auth=2793e54dfc913cb3bcf192947224ef7dc28cb33aca86d1f7e8c1cc772e7c799a&quality=70&width=1200&height=675&focal=400,204', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
#  RawArticle(run_id='DEVRUN', source_name='revista_capital', source_url='https://capital.es', article_id='revista_capital_17504326268107936', article_date='2025-06-16T17:48:00+00:00', article_title='La banca española progresa en criterios ESG, pero falta aplicar medidas más efectivas y prácticas', article_url='https://capital.es/economia/la-banca-espanola-progresa-en-criterios-esg-pero-falta-aplicar-medidas-mas-efectivas-y-practicas/129957/', article_body='La banca española ha mostrado un progreso gradual y significativo en la implementación de los criterios ambientales, sociales y de gobernanza (ESG) en su', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='revista_capital', source_url='https://capital.es', article_id='revista_capital_17504326268107944', article_date='2025-06-17T07:00:00+00:00', article_title='Híbrido, remoto y flexible, el nuevo paradigma laboral', article_url='https://capital.es/revista-capital/hibrido-remoto-y-flexible-el-nuevo-paradigma-laboral/129951/', article_body='La pandemia de la COVID-19 redefinió el espacio y el tiempo de trabajo. En 2025, las fórmulas híbridas y flexibles están más que consolidadas, formando parte', article_image_url='https://capital.es/wp-content/uploads/2025/06/Capital_Junio_2025_Especial_007.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='caracol_radio', source_url='https://caracol.com.co', article_id='caracol_radio_1750432626810795', article_date='2025-06-18T22:04:00+00:00', article_title='Impulsar las finanzas del desarrollo colombiano: una conversación clave rumbo a Sevilla', article_url='https://caracol.com.co/2025/06/18/impulsar-las-finanzas-del-desarrollo-colombiano-una-conversacion-clave-rumbo-a-sevilla/', article_body='En Bogotá expertos repiensan cómo el sector financiero puede movilizar recursos hacia el desarrollo sostenible del país. Un encuentro para construir una hoja de ruta nacional con impacto social y ambi', article_image_url='https://caracol.com.co/resizer/v2/https://cloudfront-us-east-1.images.arcpublishing.com/prisaradioco/Y7KUMB4IRVG75ONBBPUXMQR5PM.jpg?auth=988f748174d21238d042309971a4d87db4d8f9ea132d311d21cb428bdf873b21&height=800&width=1200&quality=70&smart=true', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='chequeado', source_url='https://chequeado.com', article_id='chequeado_17504326268107955', article_date='2025-06-17T21:16:00+00:00', article_title='Desinformación, inteligencia artificial y consumo de noticias: 5 claves sobre la situación en la Argentina y en el mundo', article_url='https://chequeado.com/el-explicador/desinformacion-inteligencia-artificial-y-consumo-de-noticias-5-claves-sobre-la-situacion-en-la-argentina-y-en-el-mundo/', article_body='La forma en que se consumen las noticias ha cambiado drásticamente. Mientras la televisión, la prensa escrita y los sitios web tradicionales siguen perdiendo terreno a nivel global, las', article_image_url='https://chequeado.com/wp-content/uploads/2025/06/Copia-de-Template-Nota-web-2025-06-17T181330.058-1-450x253.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_17504326268107963', article_date='2025-06-13T14:54:00+00:00', article_title='Substrate AI, cotizada en BME Growth, pacta una compra en EE UU mientras emite convertibles y saca filiales a Bolsa', article_url='https://cincodias.elpais.com/companias/2025-06-13/substrate-ai-cotizada-en-bme-growth-pacta-una-compra-en-ee-uu-mientras-emite-convertibles-y-saca-filiales-a-bolsa.html', article_body='Substrate AI, compañía de ingeniería de software cotizada en el BME Growth, ha acelerado su reestructuración financiera, con la captación de nuevos fondos a través de convertibles y la colocación en Bolsa de dos filiales, en pleno proceso de expansión, que ha incluido la adquisición de la firma estadounidense Secure HR.', article_image_url='https://imagenes.elpais.com/resizer/v2/IJHHMTZLHLEU75RJI7MGBFIUMI.jpg?auth=a0c02871246fb76ee4105c7f40fc90938ad9c89a412bbfc26129c089070f1804&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_1750432626810797', article_date='2025-06-18T07:59:00+00:00', article_title='Inversión de impacto social: las finanzas que transforman el mundo', article_url='https://cincodias.elpais.com/extras/2025-06-18/inversion-de-impacto-social-las-finanzas-que-transforman-el-mundo.html', article_body='La Cátedra de Impacto social de la Universidad Pontificia Comillas-ICADE, de la que Mapfre es patrocinadora, estudia el potencial y los retos de la inversión con este enfoque, que puede ser una herram', article_image_url='https://imagenes.elpais.com/resizer/v2/TCDQ5YTC3ZENTK4UOLLLNQGNW4.jpg?auth=2c7a8a4a3ad5e2e746f5c7b5239b7d56ab0e7ff1e3db6eaae3c986ae228b0ef2&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_1750432626810798', article_date='2025-06-18T03:30:00+00:00', article_title='Solucionar problemas globales: el mejor negocio empresarial', article_url='https://cincodias.elpais.com/legal/2025-06-18/solucionar-problemas-globales-el-mejor-negocio-empresarial.html', article_body='Otros ejemplos de empresas que conectan valor social y oportunidad económica son Alsa, empresa de transporte que apuesta por el empleo de mujeres como conductoras de autobuses en Marruecos o Mahou San Miguel que forman a jóvenes en riesgo de exclusión para trabajar como camareros.', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_17504326268107986', article_date='2025-06-20T12:13:00+00:00', article_title='Cuando la segunda generación toma el mando en la empresa familiar', article_url='https://cincodias.elpais.com/mercados-financieros/eres-tu-no-tu-dinero/2025-06-20/cuando-la-segunda-generacion-toma-el-mando-en-la-empresa-familiar.html', article_body='Sin planificación, profesionalización y comunicación, la sucesión puede convertirse en una fuente de conflicto más que en una oportunidad', article_image_url='https://imagenes.elpais.com/resizer/v2/PNV6D5O2GNHZ5ABZ37AZHDMBNA.jpg?auth=f56f841422ad21b667774d4a06f1cf1b44339cf9ce667bef461b4a0bdb5f8a66&width=414', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_17504326268107991', article_date='2025-06-14T03:40:00+00:00', article_title='La inversión ESG, bajo la lupa', article_url='https://cincodias.elpais.com/opinion/2025-06-14/la-inversion-esg-bajo-la-lupa.html', article_body='El péndulo sobre estos activos en Europa se ha movido a un punto más pragmático e inteligente y menos extremista', article_image_url='https://imagenes.elpais.com/resizer/v2/QXRBQWVQHVB3PC5OAWFU6SL23E.jpg?auth=4216aad948da76aa122d1c36847f258854cf7b71c29ef4cf3907ca1e7144ce96&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='cinco_días', source_url='https://cincodias.elpais.com', article_id='cinco_días_17504326268107996', article_date='2025-06-19T03:40:00+00:00', article_title='La edad biológica, el nuevo símbolo de estatus', article_url='https://cincodias.elpais.com/opinion/2025-06-19/la-edad-biologica-el-nuevo-simbolo-de-estatus.html', article_body='La juventud no es solo belleza, es rendimiento, productividad y capacidad de adaptación, y eso se ha convertido en una nueva forma de diferenciación social', article_image_url='https://imagenes.elpais.com/resizer/v2/JQYRPG66YZFWVIBN5KIIUH4MSU.jpg?auth=7689284d7a63fd671c03d0b736a22f9e09cf7e76dacc0eb2425dbee99dd4569a&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='contralínea', source_url='https://contralinea.com.mx', article_id='contralínea_17504326268108003', article_date='2025-06-17T21:42:00+00:00', article_title='Gobierno trabaja para garantizar la libertad de expresión: subsecretario Medina', article_url='https://contralinea.com.mx/noticias/gobierno-trabaja-para-garantizar-la-libertad-de-expresion-subsecretario-medina/', article_body='"Tengan la certeza de que estamos trabajando para garantizar la libertad de expresión, esa es la instrucción que nos ha dado la secretaria de Gobernación [Rosa Icela Rodríguez] y la presidenta [Claudi', article_image_url='https://contralinea.com.mx/wp-content/uploads/2024/01/periodismo-herramientas-1160x700-1.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='crónica_vasca', source_url='https://cronicavasca.elespanol.com', article_id='crónica_vasca_17504326268108008', article_date='2025-06-19T09:17:00+00:00', article_title='Software de recursos humanos clave para el sector salud', article_url='https://cronicavasca.elespanol.com/recomendados/20250619/software-recursos-humanos-clave-sector-salud/1003742667111_0.html', article_body='La digitalización se muestra como una elección imprescindible también para entornos sanitarios para una gestión integrada e inteligente', article_image_url='https://a1.elespanol.com/cronicavasca/2025/06/19/recomendados/1003742667129_14753218_1706x960.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='el_diario', source_url='https://diario.mx', article_id='el_diario_17504326268108015', article_date='2025-06-16T12:00:00+00:00', article_title='La inteligencia artificial de todos tan temida', article_url='https://diario.mx/opinion/2025/jun/15/la-inteligencia-artificial-de-todos-tan-temida-1070882.html', article_body='En las últimas semanas en todo el mundo, las redes sociales se saturaron de producciones con inteligencia artificial (IA) que no solo ponen en entredicho la veracidad del contenido, sino la honorabili', article_image_url='https://diario.mx/core/dmx/assets/images/2025/06/15/jose-luis-garcia-dzsOmOe8L.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='diario_correo', source_url='https://diariocorreo.pe', article_id='diario_correo_17504326268108022', article_date='2025-06-17T19:34:00+00:00', article_title='La Inteligencia Artificial que busca preservar el Centro Histórico de Arequipa', article_url='https://diariocorreo.pe/edicion/arequipa/la-inteligencia-artificial-que-busca-preservar-el-centro-historico-de-arequipa-noticia/', article_body='A 25 años de la declaración del Centro Histórico como Patrimonio Cultural de la Nación, investigadores de la San Pablo desarrollan una inteligencia artificial capaz de reconocer y preservar digitalmen', article_image_url='https://diariocorreo.pe/resizer/v2/BGNXYVHRBNCVPBRCQ3LUZ2WEAI.jpg?auth=7cf54bf5e2ae9ef9e5388f68d4778aaa0e108bb961fb1f4439cbe8c97dda3eb8&width=980&height=528&quality=75&smart=true', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='diario_correo', source_url='https://diariocorreo.pe', article_id='diario_correo_17504326268108027', article_date='2025-06-16T03:45:00+00:00', article_title='Esposo de ministra de la Mujer fue absuelto por personal designado por ella pese a estar involucrado en pérdida de donación', article_url='https://diariocorreo.pe/politica/esposo-de-ministra-de-la-mujer-fue-absuelto-por-personal-designado-por-ella-por-perdida-de-donacion-noticia/', article_body='El programa "Panorama" reveló que, pese a las pruebas, el área de Recursos Humanos absolvió a Eduardo Rodríguez Paz, luego de recibir el informe que recomendaba su suspensión.', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='diario_de_avisos', source_url='https://diariodeavisos.elespanol.com', article_id='diario_de_avisos_17504326268108034', article_date='2025-06-18T23:02:00+00:00', article_title='Actividades corporativas internas, una manera de fidelizar a los trabajadores', article_url='https://diariodeavisos.elespanol.com/2025/06/actividades-corporativas-internas-fidelizar-trabajadores/', article_body='Las empresas optan cada vez más por unas estrategias para fortalecer los equipos, motivar el talento y transmitir los valores de marca, en un momento en el que las relaciones laborales se han transfor', article_image_url='https://cdn.diariodeavisos.com/wp-content/uploads/2025/06/Actividades-corporativas-1.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra']),
#  RawArticle(run_id='DEVRUN', source_name='diario_de_avisos', source_url='https://diariodeavisos.elespanol.com', article_id='diario_de_avisos_1750432626810804', article_date='2025-06-19T09:38:00+00:00', article_title='Santa Cruz patrocinará a siete clubes del municipio con 260.000 euros', article_url='https://diariodeavisos.elespanol.com/2025/06/santa-cruz-patrocinara-a-siete-clubes-del-municipio-con-260-000-euros/', article_body='El Ayuntamiento de Santa Cruz de Tenerife ya ha definido las ayudas, en concepto de patrocinios de deportes, que recibirán siete clubes del municipio, en los que el consistorio inyectará 260.000 euros', article_image_url='https://cdn.diariodeavisos.com/wp-content/uploads/2025/06/Imagen-de-WhatsApp-2025-06-17-a-las-18.59.38_d4f49f25.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
#  RawArticle(run_id='DEVRUN', source_name='diario_del_yaqui', source_url='https://diariodelyaqui.mx', article_id='diario_del_yaqui_17504326268108048', article_date='2025-06-18T00:51:00+00:00', article_title='Va Cbtis 188 por espacios deportivos e infraestructura con La Escuela es Nuestra', article_url='https://diariodelyaqui.mx/ciudadobregon/va-cbtis-188-por-espacios-deportivos-e-infraestructura-con-la-escuela-es-nuestra/111581', article_body='Se busca lograr que los estudiantes cuenten con las condiciones para desarrollar sus actividades deportivas y académicas', article_image_url='https://blob.diariodelyaqui.mx/images/2025/06/18/cbtis-1-f97d330f-focus-0-0-1500-975.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='diario_responsable', source_url='https://diarioresponsable.com', article_id='diario_responsable_17504326268108053', article_date='2025-06-18T12:19:00+00:00', article_title='Fragmentación global y liderazgo empresarial débil amenazan los ODS', article_url='https://diarioresponsable.com/noticias/38218-fragmentacion-global-y-liderazgo-empresarial-debil-amenazan-los-ods', article_body='Un nuevo informe de Esade y la Fundación "la Caixa" advierte que apenas un 17% de los Objetivos de Desarrollo Sostenible presenta avances significativos. El estudio señala que, a pesar del aumento en', article_image_url='https://diarioresponsable.com/images-webp/articulos/full-380/ods-sostenibilidad-informe-esade-dr-copy.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='agencia_efe', source_url='https://efe.com', article_id='agencia_efe_17504326268108058', article_date='2025-06-17T08:25:00+00:00', article_title='La sobreexplotación del agua y el cambio climático impulsan la desertificación en España', article_url='https://efe.com/medio-ambiente/2025-06-17/dia-mundial-lucha-contra-desertificacion-sequia/', article_body='La sobreexplotación de los recursos hídricos ligada a la agricultura de regadío y el cambio climático impulsan la desertificación en España.', article_image_url='https://efe.com/wp-content/uploads/2025/06/desertificacion-espana.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='el_capital_financiero', source_url='https://elcapitalfinanciero.com', article_id='el_capital_financiero_17504326268108065', article_date='2025-06-17T22:06:00+00:00', article_title='La argentina Interborders amplía su presencia en Panamá por considerarlo el hub logístico de la región', article_url='https://elcapitalfinanciero.com/la-argentina-interborders-amplia-su-presencia-en-panama-por-considerarlo-el-hub-logistico-de-la-region/', article_body='La empresa especializada en comercio exterior, logística y aduana, Interborders, anunció la apertura de su sede corporativa en la ciudad de Panamá, con el objetivo de expandir su negocio y consolidar', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra']),
#  RawArticle(run_id='DEVRUN', source_name='el_comercio', source_url='https://elcomercio.pe', article_id='el_comercio_17504326268108075', article_date='2025-06-13T22:19:00+00:00', article_title='LLYC adquiere Digital Solvers ampliando su oferta de marketing', article_url='https://elcomercio.pe/economia/peru/llyc-adquiere-digital-solvers-ampliando-su-oferta-de-marketing-l-ultimas-noticia/', article_body='Digital Solvers formará parte del Grupo LLYC y continuará operando bajo la marca Digital Solvers by LLYC. Ambas compañías trabajarán en el desarrollo de sinergias e integración de su propuesta de valo', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='periódico_eldinero', source_url='https://eldinero.com.do', article_id='periódico_eldinero_17504326268108084', article_date='2025-06-16T18:50:00+00:00', article_title='Líderes deben apoyarse en la comunicación efectiva para alcanzar objetivos empresariales', article_url='https://eldinero.com.do/327160/lideres-deben-apoyarse-en-la-comunicacion-efectiva-para-alcanzar-objetivos-empresariales/', article_body='La comunicación es una herramienta fundamental para los líderes que desean alcanzar los objetivos de sus organizaciones. Según Gize Cárdenas, coach', article_image_url='https://149562642.v2.pressablecdn.com/wp-content/uploads/Gize-Cardenas-Comunicacion-Lideres.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='electro-imagen', source_url='https://electro-imagen.com', article_id='electro-imagen_1750432626810811', article_date='2025-06-20T13:58:00+00:00', article_title='Elena Fernández Angulo, nueva directora de marketing corporativo y comunicación de Samsung Iberia', article_url='https://electro-imagen.com/articulo/elena-fernandez-angulo-nueva-directora-de-marketing-corporativo-y-comunicacion-de-samsung-iberia', article_body='Samsung Electronics ha anunciado el nombramiento de Elena Fernández Angulo como nueva directora de Marketing Corporativo y Comunicación de Samsung Iberia, donde se encargará de dirigir las áreas de Publicidad y medios, Loyalty & CRM, Estrategia de marca y Comunicación.', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra']),
#  RawArticle(run_id='DEVRUN', source_name='el_nacional', source_url='https://elnacional.com.do', article_id='el_nacional_17504326268108118', article_date='2025-06-18T15:01:00+00:00', article_title='Vestuario escandaloso: ¿Una estrategia que ha perdido fuerza?', article_url='https://elnacional.com.do/vestuario-una-estrategia-que-ha-perdido-fuerza/', article_body='En RD, Tulile y Toño Rosario marcaron una época con su estilo de vestuarios estrafalario, con el que siempre llamaban la atención', article_image_url='https://elnacional.com.do/wp-content/uploads/2025/06/16_Que-Pasa_18_2p08.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='el_país', source_url='https://elpais.com', article_id='el_país_17504326268108125', article_date='2025-06-19T10:30:00+00:00', article_title="Bach pone música al 'Fausto' de Goethe", article_url='https://elpais.com/cultura/2025-06-19/bach-pone-musica-al-fausto-de-goethe.html', article_body='El Bachfest de Leipzig sigue apostando por formatos innovadores y celebra el quinto centenario de la taberna de Auerbach con una representación teatral que une los nombres de dos de sus vecinos más il', article_image_url='https://imagenes.elpais.com/resizer/v2/NEAUSYG4EBD7JABOKG4Z7E2VRM.jpg?auth=4d75440e2692be14a82784887dde521d8936db792c946438412303d21852fac4&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='transformación cultural', query_original_personas=['Ricardo Lechuga']),
#  RawArticle(run_id='DEVRUN', source_name='el_país', source_url='https://elpais.com', article_id='el_país_17504326268108132', article_date='2025-06-18T03:30:00+00:00', article_title="Propósito empresarial: ¿otra herramienta de 'marketing'?", article_url='https://elpais.com/economia/negocios/2025-06-18/proposito-empresarial-otra-herramienta-de-marketing.html', article_body='Las compañías aseguran que no solo quieren vender, sino hacer el bien. Los expertos piden cautela y diferenciar el postureo del compromiso real', article_image_url='https://imagenes.elpais.com/resizer/v2/DZSYKCJAS5HBLC66US5ME36FSM.jpeg?auth=9d4c2ed0c0fe04720ef8a66066edc9301f7889a2fa5c6a03c36b34d7370e4aba&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='el_país', source_url='https://elpais.com', article_id='el_país_1750432626810814', article_date='2025-06-19T03:30:00+00:00', article_title="En la moda del doble grado, no es oro todo lo que reluce: ¿Renta el esfuerzo? ¿Cuánto hay de 'marketing' universitario?", article_url='https://elpais.com/educacion/2025-06-19/en-la-moda-del-doble-grado-no-es-oro-todo-lo-que-reluce-renta-el-esfuerzo-cuanto-hay-de-marketing-universitario.html', article_body='Los empleadores valoran más el "sacrificio" de estos alumnos y su capacidad de aprender que los conocimientos adquiridos, según un estudio de la Comunidad de Madrid', article_image_url='https://imagenes.elpais.com/resizer/v2/LYN5JQ3HGVG67IBA2DZNL3VPFM.jpg?auth=4bd4e5d4fca380d32f43d9e240a6ad7b2dc25dd6cedbcba6867008d707db0075&width=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='emprendedores', source_url='https://emprendedores.es', article_id='emprendedores_17504326268108144', article_date='2025-06-15T06:00:00+00:00', article_title='Blindar el correo corporativo: una urgencia que el mundo empresarial no puede seguir ignorando', article_url='https://emprendedores.es/firmas/blindar-correo-corporativo/', article_body='Este experto habla sobre la vulnerabilidad de los correos electrónicos en las compañías, cómo puede afectar a su seguridad y qué debería hacerse para fortalecerla.', article_image_url='https://emprendedores.es/wp-content/uploads/ciberataque-correo-electronico.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra']),
#  RawArticle(run_id='DEVRUN', source_name='gizmodo_en_español', source_url='https://es.gizmodo.com', article_id='gizmodo_en_español_17504326268108153', article_date='2025-06-17T16:35:00+00:00', article_title='Lo que ocultaban las rocas australianas: El hallazgo que reescribe la historia del arte rupestre', article_url='https://es.gizmodo.com/lo-que-ocultaban-las-rocas-australianas-el-hallazgo-que-reescribe-la-historia-del-arte-rupestre-2000173859', article_body='Un estilo artístico desconocido, oculto durante milenios en las paredes de Kimberley, podría cambiar lo que sabíamos sobre los pueblos aborígenes. Las Figuras Naturalistas Lineales no solo rellenan un', article_image_url='https://es.gizmodo.com/app/uploads/2025/06/Diseno-sin-titulo-25-12.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='transformación cultural', query_original_personas=['Ricardo Lechuga']),
#  RawArticle(run_id='DEVRUN', source_name='gestión', source_url='https://gestion.pe', article_id='gestión_1750432626810816', article_date='2025-06-19T15:27:00+00:00', article_title='Neuralink, Matrix y la incómoda verdad: los humanos siempre fuimos programables', article_url='https://gestion.pe/blog/marketing-de-miercoles/2025/06/neuralink-matrix-y-la-incomoda-verdad-los-humanos-siempre-fuimos-programables.html', article_body='No necesitamos un chip en el cerebro para ser reprogramados. Ya lo hemos sido. Durante más de un siglo, cada tecnología, cada ideología, cada moda y cada app ha reescrito líneas de nuestro comportamie', article_image_url='https://cdna.gestion.pe/resources/dist/gestion/images/logo_fb.jpg?d=1', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='gestión', source_url='https://gestion.pe', article_id='gestión_17504326268108165', article_date='2025-06-19T16:46:00+00:00', article_title='SuperPet, veterinarias o supermercados: ¿dónde compran y cuánto gastan los los dueños de mascotas', article_url='https://gestion.pe/economia/empresas/superpet-veterinarias-o-supermercados-donde-compran-y-cuanto-gastan-los-duenos-de-mascotas-noticia/', article_body='Estudio de GRM, en alianza con VPG, revela el canal de compra preferido por los dueños de mascotas, así como las oportunidades que se observan en esta industria. Los detalles en la siguiente nota.', article_image_url='https://gestion.pe/resizer/v2/ORXASCSY3BGATBHOKNGSQP4KO4.jpg?auth=54a56a8a39244230142e37451f3ababe9f83b6833234e6456edef780ccd3b2d4&width=980&height=528&quality=75&smart=true', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='gestión', source_url='https://gestion.pe', article_id='gestión_17504326268108172', article_date='2025-06-18T11:00:00+00:00', article_title='McKinsey: Construir líderes desde la base: una urgencia para el Perú', article_url='https://gestion.pe/opinion/mckinsey-construir-lideres-desde-la-base-una-urgencia-para-el-peru-noticia/', article_body='Pasar de "ascensos por confianza" a trayectorias de liderazgo transparentes y meritocráticas es uno de los pasos más transformadores que una organización puede dar.', article_image_url='https://gestion.pe/resizer/v2/WSSPSA7T6FAE5JRNBD5L6BZNPA.jpg?auth=a4f1bf4a716d4a4372a11a5d1a57fd8f29e1847e2c3a25ba0ddc6df01d2c9190&width=980&height=528&quality=75&smart=true', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='ipmark', source_url='https://ipmark.com', article_id='ipmark_1750432626810818', article_date='2025-06-20T05:20:00+00:00', article_title='BBVA ficha a Alfonso Fernández como responsable global de marketing y ventas digitales', article_url='https://ipmark.com/bbva-ficha-a-alfonso-fernandez-como-responsable-global-de-marketing-y-ventas-digitales/', article_body='Alfonso Fernández se incorpora a BBVA como discipline head global de marketing y ventas digitales, según ha confirmado la entidad financiera. Con este nombramiento, Fernández pasará a formar parte del', article_image_url='https://ipmark.com/wp-content/uploads/alfonso-fernandez__4139-1.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='ipmark', source_url='https://ipmark.com', article_id='ipmark_1750432626810819', article_date='2025-06-20T10:26:00+00:00', article_title='La fusión entre marketing y gaming', article_url='https://ipmark.com/la-fusion-entre-marketing-y-gaming/', article_body='En los últimos años, la transformación del entretenimiento ha obligado al marketing a adaptarse a un nuevo terreno como el', article_image_url='https://ipmark.com/wp-content/uploads/marketing-strategy.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='la_opinión', source_url='https://laopinion.com', article_id='la_opinión_17504326268108194', article_date='2025-06-18T17:34:00+00:00', article_title='Empleado de Pensilvania mata a compañero de trabajo y confiesa en correo a Recursos Humanos', article_url='https://laopinion.com/2025/06/18/empleado-de-pensilvania-mata-a-companero-de-trabajo-y-confiesa-en-correo-a-recursos-humanos/', article_body='Christopher Wasnetsky, de 36 años, fue arrestado el sábado por la madrugada, acusado de asesinar a Jeff Moeller, de 44 años', article_image_url='https://laopinion.com/wp-content/uploads/sites/3/2025/06/arresto-de-un-hombre-3.jpg?w=1200', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='la_república', source_url='https://larepublica.pe', article_id='la_república_175043262681082', article_date='2025-06-13T14:36:00+00:00', article_title='Comerciante amarra presas de pollo frito para evitar robos en su carretilla: "Eso es marketing"', article_url='https://larepublica.pe/tendencias/2025/06/13/comerciante-amarra-presas-de-pollo-frito-para-evitar-robos-en-su-carretilla-eso-es-marketing-404963', article_body='Vendedora en Tacora creó una estrategia viral para evitar el robo de sus productos. Al amarrar las presas de pollo frito, generó varias reacciones en redes.', article_image_url='https://imgmedia.larepublica.pe/1200x630/larepublica/original/2025/06/13/684c8b2f58e63b3f0a0d7252.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='listín_diario', source_url='https://listindiario.com', article_id='listín_diario_17504326268108208', article_date='2025-06-18T04:00:00+00:00', article_title='Economistas creen positiva liberación de fondos del encaje para impulsar la economía', article_url='https://listindiario.com/economia/finanzas/20250618/economistas-creen-positiva-liberacion-fondos-encaje-impulsar-economia_862349.html', article_body='Economistas y empresarios valoran la liberación de los fondos del encaje legal liberados por el Banco Central para dinamizar la economía, y enfatizan en la necesidad de reformas estructurales y de verificar que vayan a sectores que generen empleos y crecimiento sostenible.', article_image_url='https://listindiario.com/files/main_image/uploads/2025/01/01/67758c52da885.jpeg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='listín_diario', source_url='https://listindiario.com', article_id='listín_diario_17504326268108215', article_date='2025-06-18T15:12:00+00:00', article_title='Economistas creen positiva liberación de fondos del encaje legal para impulsar la economía', article_url='https://listindiario.com/economia/finanzas/20250618/economistas-liberacion-fondos-encaje-legal-impulsar-economia_862349.html', article_body='Economistas y empresarios valoran la liberación de los fondos del encaje legal liberados por el Banco Central para dinamizar la economía, y enfatizan en la necesidad de reformas estructurales y de verificar que vayan a sectores que generen empleos y crecimiento sostenible.', article_image_url='https://listindiario.com/files/main_image/uploads/2025/01/01/67758c52da885.jpeg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='finanzas sostenibles', query_original_personas=['Salvador Martínez']),
#  RawArticle(run_id='DEVRUN', source_name='marketing_4_ecommerce', source_url='https://marketing4ecommerce.mx', article_id='marketing_4_ecommerce_17504326268108222', article_date='2025-06-19T18:40:00+00:00', article_title='Clientify desarrolla una nueva generación de bots con IA para WhatsApp', article_url='https://marketing4ecommerce.mx/clientify-bots-con-ia-para-whatsapp/', article_body='Descubre cómo Clientify transforma la relación cliente-empresa con inteligencia artificial, automatización y nuevas funciones en WhatsApp.', article_image_url='https://marketing4ecommerce.mx/wp-content/uploads/2025/06/chat-ia-768x461.jpg.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='marketing_4_ecommerce', source_url='https://marketing4ecommerce.mx', article_id='marketing_4_ecommerce_17504326268108232', article_date='2025-06-18T15:29:00+00:00', article_title='Hogarth México fortalece su equipo con Tania Torres como Head of Client Services and Business Growth', article_url='https://marketing4ecommerce.mx/hogarth-mexico-tania-torres/', article_body='Con más de 11 años de trayectoria en publicidad, Tania Torres buscará garantizar el crecimiento sostenible de la agencia en México.', article_image_url='https://marketing4ecommerce.mx/wp-content/uploads/2025/06/tania-torres-hogarth-mexico.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='marketing_4_ecommerce', source_url='https://marketing4ecommerce.net', article_id='marketing_4_ecommerce_17504326268108237', article_date='2025-06-19T10:54:00+00:00', article_title='Meta lanza nuevas herramientas para anunciantes de generación de texto, imágenes y vídeos con IA', article_url='https://marketing4ecommerce.net/meta-ia-anunciantes/', article_body='Crear imágenes y textos manteniendo un branding coherente o generar vídeos animados a partir de imágenes fijas son algunas de las novedades.', article_image_url='https://marketing4ecommerce.net/wp-content/uploads/2025/06/nuevas-herramientas-de-ia-generativa-para-anunciantes.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='marketing_4_ecommerce', source_url='https://marketing4ecommerce.net', article_id='marketing_4_ecommerce_17504326268108242', article_date='2025-06-20T08:17:00+00:00', article_title='Ya puedes crear vídeos (con sonido) usando inteligencia artificial directamente desde Canva', article_url='https://marketing4ecommerce.net/video-ai-canva/', article_body='Esta nueva función está disponible para los usuarios de planes de pago (Pro, Teams y Enterprise), limitada a 5 generaciones de vídeo por mes.', article_image_url='https://marketing4ecommerce.net/wp-content/uploads/2025/06/canva-ia-video-2-2-1024x614.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='miputumayo_noticias', source_url='https://miputumayo.com.co', article_id='miputumayo_noticias_17504326268108249', article_date='2025-06-16T20:42:00+00:00', article_title='Geopark, compañia matriz de Amerisur, gana premio por su liderazgo en respeto a los derechos humanos y conducta empresarial responsable', article_url='https://miputumayo.com.co/2025/06/16/geopark-compania-matriz-de-amerisur-gana-premio-por-su-liderazgo-en-respeto-a-los-derechos-humanos-y-conducta-empresarial-responsable/', article_body='Publimayo La Compañía fue reconocida por su práctica estructural, preventiva y participativa, diseñada para promover el respeto de los derechos humanos y aportar al desarrollo sostenible de los territ', article_image_url='https://miputumayo.com.co/wp-content/uploads/2025/06/Imagen-de-WhatsApp-2025-06-16-a-las-16.40.37_f97e2091.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='misionesonline', source_url='https://misionesonline.net', article_id='misionesonline_17504326268108256', article_date='2025-06-19T12:14:00+00:00', article_title='Este 4 de julio habrá una charla-taller de nivel internacional sobre Inteligencia Artificial Relacional', article_url='https://misionesonline.net/2025/06/19/charla-sobre-inteligencia-artificial/', article_body='Con el objetivo de integrar los sistemas de inteligencia artificial en la enseñanza, el viernes 4 de julio a partir de las 18hs en el Hotel Julio César, se llevará a cabo una charla-taller de nivel in', article_image_url='https://static.misionesonline.news/wp-content/uploads/2025/06/iar-web.png', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='misionesonline', source_url='https://misionesonline.net', article_id='misionesonline_17504326268108263', article_date='2025-06-19T15:44:00+00:00', article_title='Fénix Inmobiliaria apuesta a la formación continua de su equipo junto al INCADE', article_url='https://misionesonline.net/2025/06/19/fenix-inmobiliaria-16/', article_body='En un paso innovador hacia la profesionalización del rubro inmobiliario en el NEA, Fénix Inmobiliaria anunció una alianza estratégica con INCADE Escuela de', article_image_url='https://static.misionesonline.news/wp-content/uploads/2025/06/WhatsApp-Image-2025-06-19-at-11.56.08-AM.jpeg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='mvs_noticias', source_url='https://mvsnoticias.com', article_id='mvs_noticias_1750432626810827', article_date='2025-06-13T22:29:00+00:00', article_title='Caliente.mx y Concacaf anuncian histórico patrocinio para la Copa Oro 2025', article_url='https://mvsnoticias.com/deportes/2025/6/13/calientemx-concacaf-anuncian-historico-patrocinio-para-la-copa-oro-2025-697046.html', article_body='Por primera vez en la historia, una casa de apuestas será patrocinadora oficial del torneo más importante de selecciones nacionales en la región.', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
# ...
#  RawArticle(run_id='DEVRUN', source_name='rrhh_digital', source_url='https://www.rrhhdigital.com', article_id='rrhh_digital_17504326268110147', article_date='2025-06-20T09:00:00+00:00', article_title='Si las empresas quieren ser competitivas, el área de RRHH debe liderar la transformación digital', article_url='https://www.rrhhdigital.com/secciones/empresa/775277/si-las-empresas-quieren-ser-competitivas-el-area-de-rrhh-debe-liderar-la-transformacion-digital/', article_body='Según el último informe LiceoTIC, los departamentos de Recursos Humanos tienen una oportunidad estratégica única para convertirse en el verdadero motor de la transformación digital en las organizacion', article_image_url='https://www.rrhhdigital.com/wp-content/uploads/2025/04/jefe-trabajo-twitter.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='rrhh_digital', source_url='https://www.rrhhdigital.com', article_id='rrhh_digital_17504326268110154', article_date='2025-06-17T00:44:00+00:00', article_title='La paradoja del liderazgo moderno', article_url='https://www.rrhhdigital.com/secciones/liderazgo/774991/la-paradoja-del-liderazgo-moderno/', article_body='El liderazgo empresarial del siglo XXI se enfrenta a demandas aparentemente contradictorias. Los directivos deben inspirar a sus equipos con visión y propósito, pero a la vez cumplir objetivos product', article_image_url='https://www.rrhhdigital.com/wp-content/uploads/2024/02/TWITTER-jefe.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='rrhh_press', source_url='https://www.rrhhpress.com', article_id='rrhh_press_17504326268110158', article_date='2025-06-19T19:08:00+00:00', article_title='Elena Fernández, nueva directora de marketing corporativo y comunicación de Samsung Iberia', article_url='https://www.rrhhpress.com/gente/61806-samsung-elena-fernandez-directora-marketing-comunicacion', article_body='Redacción. Samsung Electronics ha anunciado el nombramiento de Elena Fernández Angulo como nueva directora de marketing corporativo y comunicación de Samsung Iberia, responsabilizándose de dirigir las áreas de Publicidad y medios, Loyalty & CRM, Estrategia de marca y Comunicación.', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='rrhh_press', source_url='https://www.rrhhpress.com', article_id='rrhh_press_17504326268110166', article_date='2025-06-16T09:13:00+00:00', article_title='Ocho maneras de practicar un liderazgo consciente a través de la medición del tiempo', article_url='https://www.rrhhpress.com/tendencias/61779-liderazgo-consciente-medicion-tiempo-ocho-formas-efectivas', article_body='Redacción. El liderazgo consciente es una tendencia que gana relevancia en el management como palanca del crecimiento organizacional. Este estilo de liderazgo parte de la idea de que, para poder guiar', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='rtve', source_url='https://www.rtve.es', article_id='rtve_17504326268110173', article_date='2025-06-19T10:39:00+00:00', article_title='Las siete diferencias entre el desarrollo de la inteligencia artificial en Estados Unidos y la Unión Europea', article_url='https://www.rtve.es/noticias/20250619/siete-diferencias-inteligencia-artificial-estados-unidos-union-europea/16448726.shtml', article_body='Mientras Estados Unidos apuesta por el crecimiento, la Unión Europea defiende un enfoque ético', article_image_url='https://img.rtve.es/imagenes/siete-diferencias-inteligencia-artificial-estados-unidos-union-europea/01739529229458.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='rtve', source_url='https://www.rtve.es', article_id='rtve_1750432626811018', article_date='2025-06-17T10:44:00+00:00', article_title="'En Portada' muestra la batalla por el control de los minerales estratégicos", article_url='https://www.rtve.es/rtve/20250617/portada-muestra-batalla-control-minerales-estrategicos/16628487.shtml', article_body="'En Portada', presentado por Lorenzo Milá, estrena el reportaje 'Bienvenido, Mister Lobito', en el que aborda la batalla que libran las grandes potencias mundiales por el control de los minerales estratégicos. Uno de sus objetivos es el dominio del Corredor de Lobito.", article_image_url='https://img.rtve.es/imagenes/portada-muestra-batalla-control-minerales-estrategicos/01750156724676.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='señal_colombia', source_url='https://www.senalcolombia.tv', article_id='señal_colombia_17504326268110185', article_date='2025-06-18T16:38:00+00:00', article_title='Día Mundial de los Refugiados: memoria y humanidad frente al exilio', article_url='https://www.senalcolombia.tv/dia-mundial-del-refugiado-20-junio', article_body='El 20 de junio se conmemora el Día Mundial de los Refugiados, una fecha para honrar a quienes han tenido que exiliarse de sus hogares en busca de un futuro mejor, con la esperanza de un cambio real.', article_image_url='https://s3.amazonaws.com/rtvc-assets-senalcolombia.gov.co/s3fs-public/field/image/Sin+título-1_4.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='transformación cultural', query_original_personas=['Ricardo Lechuga']),
#  RawArticle(run_id='DEVRUN', source_name='superdeporte', source_url='https://www.superdeporte.es', article_id='superdeporte_17504326268110192', article_date='2025-06-20T08:48:00+00:00', article_title='CaixaBank renueva su patrocinio en el Medio y el Maratón Valencia hasta 2027', article_url='https://www.superdeporte.es/polideportivo/2025/06/20/caixabank-renueva-patrocinio-medio-maraton-valencia-hasta-2027-118838171.html', article_body='La entidad financiera, que forma parte de los patrocinadores de las pruebas desde hace ya 13 años, mantiene su apuesta por el Medio Maratón y Maratón Valencia, con los que comparte valores como el esf', article_image_url='https://estaticos-cdn.prensaiberica.es/clip/e3b487c5-fd94-48b2-b044-746efd7fbbb1_16-9-discover-aspect-ratio_default_0.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='patrocinios deportivos', query_original_personas=['Jofre Riera']),
#  RawArticle(run_id='DEVRUN', source_name='teknlife.com', source_url='https://www.teknlife.com', article_id='teknlife.com_17504326268110197', article_date='2025-06-20T11:00:00+00:00', article_title='Las claves del marketing en 2025: ¿Qué priorizarán los expertos?', article_url='https://www.teknlife.com/las-claves-del-marketing-en-2025-que-priorizaran-los-expertos/', article_body='El último informe de Forrester destaca las preocupaciones y estrategias clave que enfrentarán los responsables de marketing en 2025, centrándose en la necesidad de demostrar resultados, personalizar e', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='telemadrid', source_url='https://www.telemadrid.es', article_id='telemadrid_17504326268110206', article_date='2025-06-19T14:07:00+00:00', article_title='Kuikads, la startup madrileña que revoluciona el marketing con IA y vídeos publicitarios personalizados', article_url='https://www.telemadrid.es/programas/madrid-trabaja/Kuikads-la-startup-madrilena-que-revoluciona-el-marketing-con-IA-y-videos-publicitarios-personalizados-9-2790110967--20250619040700.html', article_body='Kuikads, una joven startup con sede en Madrid, ha ganado el vertical Digital & Tech Solution\xa0en el\xa0 South Summit 2025, el evento de emprendimiento más importante del país. Para conocer desde dentro có', article_image_url='https://www.telemadrid.es/2025/06/19/programas/madrid-trabaja/_2790030993_49708813_1300x731.png', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='marketing', query_original_personas=['Jaume Alemany']),
#  RawArticle(run_id='DEVRUN', source_name='telemetro', source_url='https://www.telemetro.com', article_id='telemetro_1750432626811021', article_date='2025-06-16T16:46:00+00:00', article_title='Facultad de Comunicación de la Universidad de Panamá crece con nueva unidad académica', article_url='https://www.telemetro.com/nacionales/facultad-comunicacion-la-universidad-panama-crece-nueva-unidad-academica-n6043376', article_body='La Universidad de Panamá aprueba creación de una nueva escuela en la Facultad de Comunicación Social. El Consejo Académico de la Universidad de Panamá aprobó la propuesta para la creación de la Escuela de Gestión de Eventos y Protocolo, que pasará a formar parte de la Facultad de Comunicación Social como su quinta unidad académica.', article_image_url='https://media.telemetro.com/p/fb701f88148073ab918c6384a2d5bdb7/adjuntos/311/imagenes/018/882/0018882339/1200x675/smart/facultad-comunicacion-social-up.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='comunicación corporativa', query_original_personas=['Fede Segarra']),
#  RawArticle(run_id='DEVRUN', source_name='tiempo_la_noticia_digital', source_url='https://www.tiempo.com.mx', article_id='tiempo_la_noticia_digital_17504326268110218', article_date='2025-06-17T16:32:00+00:00', article_title='Eduardo Turnbull comparte claves para construir equipos de alto valor', article_url='https://www.tiempo.com.mx/noticia/eduardo_turnbull_liderazgo_generativo_equipos_alto_valor_chihuahua/', article_body='Con una invitación a repensar el liderazgo desde las conversaciones, la confianza y el compromiso, el coach ejecutivo Eduardo Turnbull impartió la conferencia\xa0"Equipos que generan alto valor y resulta', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='tiempo_sur', source_url='https://www.tiemposur.com.ar', article_id='tiempo_sur_17504326268110223', article_date='2025-06-18T22:46:00+00:00', article_title='Mariano Mazzaglia anticipó que el pago de aguinaldos sería sobre el cierre junio', article_url='https://www.tiemposur.com.ar/info-general/mariano-mazzaglia-anticipo-que-el-pago-de-aguinaldos-seria-sobre-el-cierre-junio', article_body='El subsecretario de Recursos Humanos señaló que con ingresos que se encuentran por debajo de lo esperado y un desfasaje cercano a los 2 mil millones de pesos, el municipio aún gestiona recursos para c', article_image_url='https://www.tiemposur.com.ar/uploads/noticia_galeria/2025/06/18/file_229125_zocalo801.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='todojujuy.com', source_url='https://www.todojujuy.com', article_id='todojujuy.com_17504326268110228', article_date='2025-06-13T20:51:00+00:00', article_title='Tras la condena, estos son los recursos de Cristina Kirchner en el plano internacional', article_url='https://www.todojujuy.com/politica/tras-la-condena-estos-son-los-recursos-cristina-kirchner-el-plano-internacional-n274699', article_body='El equipo legal de la ex mandataria presentó una denuncia en la Corte Penal Internacional y prepara otra para la Comisión Interamericana.', article_image_url='https://media.todojujuy.com/p/9854801b1a50d2136a2dcf8560339fa8/adjuntos/227/imagenes/003/408/0003408868/1200x675/smart/la-defensa-la-ex-presidenta-ya-radico-una-denuncia-la-corte-penal-internacional.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández']),
#  RawArticle(run_id='DEVRUN', source_name='tus_buenas_noticias', source_url='https://www.tusbuenasnoticias.com', article_id='tus_buenas_noticias_17504326268110237', article_date='2025-06-17T00:24:00+00:00', article_title='Transformación Digital en Latinoamérica: ¿Dónde estamos y hacia dónde vamos?', article_url='https://www.tusbuenasnoticias.com/noticias/buenas-noticias/2025/06/16/46631-transformacion-digital-avanza-en-latinoamerica-y-mexico', article_body='Descubre los avances y desafíos de la Transformación Digital en México y Latinoamérica según el Think Digital Report 2024. ¡Conoce el panorama actual!', article_image_url='https://blob.tusbuenasnoticias.com/images/2025/06/17/copia-de-portadas-sinaloa-7-7d106bbe-focus-0-0-1200-600.webp', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='transformación cultural', query_original_personas=['Ricardo Lechuga']),
#  RawArticle(run_id='DEVRUN', source_name='vanguardia', source_url='https://www.vanguardia.com', article_id='vanguardia_17504326268110244', article_date='2025-06-14T05:00:00+00:00', article_title='Llanera La Victoria: 30 años de liderazgo, sabor y tradición familiar', article_url='https://www.vanguardia.com/informes-comerciales/2025/06/14/llanera-la-victoria-30-anos-de-liderazgo-sabor-y-tradicion-familiar/', article_body='Desde el corazón de La Mesa de los Santos, Llanera La Victoria ha escrito una historia que ya suma 30 años y la sitúa como referente gastronómico de esta zona turística, a escasos 35 minutos del área', article_image_url='https://www.vanguardia.com/resizer/v2/CI5P6IGZOZCWZDIMKLRKHZMZX4.jpg?auth=0a3922a9186c3c741ed6dcfdade2f2f06b8e21b2a31fa9b915661b3078fe9bef&smart=true&width=1200&height=630&quality=70', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='liderazgo empresarial', query_original_personas=['Jorge Villavecchia']),
#  RawArticle(run_id='DEVRUN', source_name='vida_nueva', source_url='https://www.vidanuevadigital.com', article_id='vida_nueva_1750432626811025', article_date='2025-06-20T11:39:00+00:00', article_title='León XIV quiere una inteligencia artificial que ayude a "generar una sociedad global más auténticamente justa y humana"', article_url='https://www.vidanuevadigital.com/2025/06/20/leon-xiv-quiere-una-inteligencia-artificial-que-ayude-a-generar-una-sociedad-global-mas-autenticamente-justa-y-humana/', article_body='Desde ayer hasta hoy, 20 de junio, Roma está acogiendo la Segunda Conferencia Anual sobre Inteligencia Artificial, Ética y Gobierno Corporativo.', article_image_url='https://www.vidanuevadigital.com/wp-content/uploads/2025/01/inteligencia-artificial-robot-flor-mujer.jpg', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='inteligencia artificial', query_original_personas=['Laura Gil']),
#  RawArticle(run_id='DEVRUN', source_name='periódico_zócalo', source_url='https://www.zocalo.com.mx', article_id='periódico_zócalo_17504326268110256', article_date='2025-06-19T10:50:00+00:00', article_title='Inaugura CBTIS 54 un laboratorio de cómputo', article_url='https://www.zocalo.com.mx/inaugura-cbtis-54-un-laboratorio-de-computo/', article_body='Acuña, Coahuila.- Con el objetivo de atender las necesidades académicas de los estudiantes de las especialidades de Contabilidad y Administración de Recursos Humanos, la', article_image_url='', article_language='es', crawled_at='2025-06-20T17:17:06.811882', ddgs_search_query='recursos humanos', query_original_personas=['Elísabeth Hernández'])]
