# %%
import pandas as pd
import json
import os
from dotenv import load_dotenv
from datetime import datetime
from pathlib import Path
from time import sleep

# %%
load_dotenv('../.env')
# Out:
# True

# %%
TASK_NAME = "source_parsing_v0"

INPUT_DATA_PATH = f"../local_tests_data/azure_openai_batch_processing_files/"
run_n = len(os.listdir(INPUT_DATA_PATH))
RUNID = f"RUNID_{run_n}"
INPUT_DATA_PATH = f"../local_tests_data/azure_openai_batch_processing_files/{RUNID}/{TASK_NAME}/OUTPUTS/"

RUN_TIME = datetime.strftime(datetime.now(), '%Y-%m-%d %H:%M:%S')

OUTPUT_DATA_PATH = f"../local_tests_data/raw_articles_list/{RUNID}/"

os.makedirs(OUTPUT_DATA_PATH, exist_ok=True)

print(f"Run ID: {RUNID} at {RUN_TIME}")
# Out:
# Run ID: RUNID_1 at 2025-05-29 17:16:04

# %%
def read_outputs():
    outputs = []
    for filename in os.listdir(INPUT_DATA_PATH):
        if filename.endswith('.jsonl'):
            with open(os.path.join(INPUT_DATA_PATH, filename), 'r') as f:
                    lines_raw = f.readlines()
                    for line in lines_raw:
                        output_dict = json.loads(line)
                        model = output_dict.get("response").get("body").get("model")
                        line_id = output_dict.get("custom_id")
                        content_json = output_dict.get("response").get("body").get("choices")[0].get("message").get("content")
                        content = json.loads(content_json)
                        outputs.append({
                            "model": model,
                            "line_id": line_id,
                            "content": content
                        })
    return outputs

import glob
import os

def get_previously_crawled_article_titles():

    root_dir = Path(OUTPUT_DATA_PATH).parent
    pattern = '*.json'               

    search_path = os.path.join(root_dir, '**', pattern)
    all_filenames = glob.glob(search_path, recursive=True)

    previously_crawled_article_titles = []
    for filepath in all_filenames:
        with open(filepath, 'r') as file:
            data = json.load(file)
            for item in data:
                if 'article_title' in item:
                    previously_crawled_article_titles.append(item['article_title'])

    return previously_crawled_article_titles

# %%
get_previously_crawled_article_titles()
# Out:
# ['Bioprinted organs ‘10–15 years away,’ says startup regenerating dog skin',
#  '‘Purest meat alternative’ to grow in Swedish mycoprotein factory',
#  'Can geothermal startups drill Europe to clean energy independence?',
#  'TNW Backstage tunes into the future of earbuds',
#  'Elon Musk’s Grok chatbot banned by a quarter of European firms',
#  'ENISA ya cuenta con más de medio millar de startups certificadas',
#  '7 metas que deberán marcar la relación de las empresas con la tecnología en 2024',
#  'Apple es la compañía tecnológica que más ganancias tiene por empleado',
#  'Cómo mantener el impulso de tu startup durante la época navideña',
#  'Google paga 5.000 millones de dólares para resolver una demanda colectiva',
#  'Meta, la matriz de Facebook, planea abrir tiendas físicas para vender sus gafas inteligentes',
#  'Palo sideral a Elon Musk: esto es lo que cuesta el megacohete Starship que ha explotado sobre el Índico',
#  'El ecosistema tecnológico español crece un 22% y Madrid desplaza a Barcelona como capital de la innovación',
#  'Las ventas de Tesla siguen desplomándose en Europa pese al crecimiento de los coches eléctricos',
#  'Securitas Direct ultima su salida a Bolsa con una valoración superior a los 20.000 millones de euros',
#  'El CEO de Duolingo revela 5 formas en las que la IA le ayudará a decidir el futuro de su plantilla',
#  'Esta es la historia jamás contada de cómo la startup de programación más prometedora de Silicon Valley estuvo a punto de desaparecer',
#  '335 millones menos en estafas: cómo Visa bloqueó el 75% de las tarjetas comprometidas en una operación criminal con inteligencia artificial',
#  'Así lograron las compañías de medios tradicionales la rentabilidad en el streaming: menos Netflix, más ADN propio',
#  'Instagram ofrece pagar a los creadores de contenido hasta 18.000 euros por atraer personas a la aplicación',
#  'Brian Chesky (Airbnb) cree que hay un "lado positivo" en montar negocios en una economía inestable',
#  'MF Talent premia el talento y la innovación e impulsa la IA y la ciberseguridad como motores de un futuro más sostenible',
#  'Xiaomi lanza su segundo coche eléctrico: su YU7 es la nueva amenaza para Tesla en China',
#  'Cook ignora a Trump: Apple ampliará su cadena de suministro en India con una planta de 1.300 millones de euros',
#  'Esta es la verdadera razón por la que OpenAI se gasta 5.750 millones de euros en hacerse con la startup de IA de Jony Ive',
#  'OpenAI compra una startup de hardware de IA al diseñador del iPhone por casi 5.750 millones euros',
#  'Hacienda te llama solo desde este número de teléfono, el resto son estafas',
#  'Sergey Brin (Google) explica por qué ha vuelto a la empresa para trabajar en IA "prácticamente todos los días"']

# %%
previously_crawled_article_titles = get_previously_crawled_article_titles()

new_raw_articles_list = []
for output in read_outputs():
    model = output['model']
    line_id = output['line_id']
    run_id, task_name, source_name = line_id.split("--")
    content = output['content']

    article_links_list = content.get("article_links_list", [])
    for article_link in article_links_list:
        article_title = article_link.get("title", "")
        article_url = article_link.get("url", "")
        article_keywords = article_link.get("keywords", [])
        article_language = article_link.get("language", "")
        article_id = source_name + "--" + datetime.now().strftime('%Y%m%d%H%M%S%f')

        sleep(0.01)

        if article_title in previously_crawled_article_titles:
            print(f"Skipping {article_title} as it has already been crawled.")
            continue

        new_raw_articles_list.append({
            "model": model,
            "run_id": run_id,
            "task_name": task_name,
            "source_name": source_name,
            "article_id": article_id,
            "article_title": article_title,
            "article_url": article_url,
            "article_keywords": article_keywords,
            "article_language": article_language,
            "crawled_at": RUN_TIME
        })

# %%
new_raw_articles_list
# Out:
# [{'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'the_next_web',
#   'article_id': 'the_next_web--20250529174107305291',
#   'article_title': 'Bioprinted organs ‘10–15 years away,’ says startup regenerating dog skin',
#   'article_url': 'https://thenextweb.com/news/bioprinting-human-organs-in-10-years',
#   'article_keywords': ['bioprinting', 'human organs', 'deep tech'],
#   'article_language': 'en',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'the_next_web',
#   'article_id': 'the_next_web--20250529174107315426',
#   'article_title': '‘Purest meat alternative’ to grow in Swedish mycoprotein factory',
#   'article_url': 'https://thenextweb.com/news/purest-meat-alternative-to-grow-in-swedish-mycoprotein-factory',
#   'article_keywords': ['meat alternative', 'sustainability', 'factory'],
#   'article_language': 'en',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'the_next_web',
#   'article_id': 'the_next_web--20250529174107325634',
#   'article_title': 'Can geothermal startups drill Europe to clean energy independence?',
#   'article_url': 'https://thenextweb.com/news/geothermal-energy-startups-europe-energy-security',
#   'article_keywords': ['geothermal', 'clean energy', 'startups'],
#   'article_language': 'en',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'the_next_web',
#   'article_id': 'the_next_web--20250529174107335824',
#   'article_title': 'TNW Backstage tunes into the future of earbuds',
#   'article_url': 'https://thenextweb.com/news/tnw-backstage-explores-future-earbuds-breggz',
#   'article_keywords': ['technology', 'earbuds', 'deep tech'],
#   'article_language': 'en',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'the_next_web',
#   'article_id': 'the_next_web--20250529174107345981',
#   'article_title': 'Elon Musk’s Grok chatbot banned by a quarter of European firms',
#   'article_url': 'https://thenextweb.com/news/elon-musks-grok-chatbot-banned-by-european-firms',
#   'article_keywords': ['Elon Musk', 'chatbot', 'data security'],
#   'article_language': 'en',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'itespresso',
#   'article_id': 'itespresso--20250529174107356190',
#   'article_title': 'ENISA ya cuenta con más de medio millar de startups certificadas',
#   'article_url': 'https://www.itespresso.es/enisa-startups-certificadas-243919.html',
#   'article_keywords': ['ENISA', 'certified startups', 'technology news'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'itespresso',
#   'article_id': 'itespresso--20250529174107366492',
#   'article_title': '7 metas que deberán marcar la relación de las empresas con la tecnología en 2024',
#   'article_url': 'https://www.itespresso.es/objetivos-relacion-empresas-tecnologia-243911.html',
#   'article_keywords': ['companies and technology', 'goals 2024'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'itespresso',
#   'article_id': 'itespresso--20250529174107376792',
#   'article_title': 'Apple es la compañía tecnológica que más ganancias tiene por empleado',
#   'article_url': 'https://www.itespresso.es/apple-ganancias-empleado-243925.html',
#   'article_keywords': ['Apple', 'employee earnings'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'itespresso',
#   'article_id': 'itespresso--20250529174107386958',
#   'article_title': 'Cómo mantener el impulso de tu startup durante la época navideña',
#   'article_url': 'https://www.itespresso.es/startups-en-navidad-243832.html',
#   'article_keywords': ['startups', 'christmas season'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'itespresso',
#   'article_id': 'itespresso--20250529174107397118',
#   'article_title': 'Google paga 5.000 millones de dólares para resolver una demanda colectiva',
#   'article_url': 'https://www.itespresso.es/google-pago-privacidad-chrome-244035.html',
#   'article_keywords': ['Google', 'privacy lawsuit'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107407274',
#   'article_title': 'Meta, la matriz de Facebook, planea abrir tiendas físicas para vender sus gafas inteligentes',
#   'article_url': 'https://www.businessinsider.es/tecnologia/meta-matriz-facebook-planea-abrir-tiendas-fisicas-vender-gafas-inteligentes-1463955',
#   'article_keywords': ['Meta',
#    'Facebook',
#    'tiendas físicas',
#    'gafas inteligentes'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107417571',
#   'article_title': 'Palo sideral a Elon Musk: esto es lo que cuesta el megacohete Starship que ha explotado sobre el Índico',
#   'article_url': 'https://www.businessinsider.es/tecnologia/palo-sideral-elon-musk-cuesta-megacohete-starship-ha-explotado-indico-1463875',
#   'article_keywords': ['Elon Musk', 'Starship', 'espacio', 'colonización'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107427805',
#   'article_title': 'El ecosistema tecnológico español crece un 22% y Madrid desplaza a Barcelona como capital de la innovación',
#   'article_url': 'https://www.businessinsider.es/tecnologia/ecosistema-tecnologico-espanol-crece-22-madrid-desplaza-barcelona-como-capital-innovacion-1463601',
#   'article_keywords': ['ecosistema', 'tecnología', 'innovación', 'España'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107437986',
#   'article_title': 'Las ventas de Tesla siguen desplomándose en Europa pese al crecimiento de los coches eléctricos',
#   'article_url': 'https://www.businessinsider.es/tecnologia/ventas-tesla-siguen-desplomandose-europa-pese-crecimiento-coches-electricos-1463652',
#   'article_keywords': ['Tesla', 'coches eléctricos', 'ventas', 'Europa'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107448174',
#   'article_title': 'Securitas Direct ultima su salida a Bolsa con una valoración superior a los 20.000 millones de euros',
#   'article_url': 'https://www.businessinsider.es/tecnologia/securitas-direct-ultima-salida-bolsa-valoracion-superior-20000-millones-euros-1463571',
#   'article_keywords': ['Securitas Direct', 'Bolsa', 'valoración', 'OPV'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107458396',
#   'article_title': 'El CEO de Duolingo revela 5 formas en las que la IA le ayudará a decidir el futuro de su plantilla',
#   'article_url': 'https://www.businessinsider.es/tecnologia/ceo-duolingo-revela-5-formas-ia-ayudara-decidir-futuro-plantilla-1458249',
#   'article_keywords': ['Duolingo', 'IA', 'plantilla', 'empresa'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107468679',
#   'article_title': 'Esta es la historia jamás contada de cómo la startup de programación más prometedora de Silicon Valley estuvo a punto de desaparecer',
#   'article_url': 'https://www.businessinsider.es/tecnologia/historia-jamas-contada-como-startup-programacion-prometedora-silicon-valley-estuvo-punto-desaparecer-1462044',
#   'article_keywords': ['StackBlitz',
#    'startup',
#    'programación',
#    'Silicon Valley'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107478998',
#   'article_title': '335 millones menos en estafas: cómo Visa bloqueó el 75% de las tarjetas comprometidas en una operación criminal con inteligencia artificial',
#   'article_url': 'https://www.businessinsider.es/tecnologia/335-millones-menos-estafas-como-visa-bloqueo-75-tarjetas-comprometidas-operacion-criminal-inteligencia-artificial-1462936',
#   'article_keywords': ['Visa',
#    'estafas',
#    'inteligencia artificial',
#    'tarjetas'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107489354',
#   'article_title': 'Así lograron las compañías de medios tradicionales la rentabilidad en el streaming: menos Netflix, más ADN propio',
#   'article_url': 'https://www.businessinsider.es/tecnologia/lograron-companias-medios-tradicionales-rentabilidad-streaming-menos-netflix-adn-propio-1463069',
#   'article_keywords': ['streaming',
#    'medios tradicionales',
#    'rentabilidad',
#    'Netflix'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107499629',
#   'article_title': 'Instagram ofrece pagar a los creadores de contenido hasta 18.000 euros por atraer personas a la aplicación',
#   'article_url': 'https://www.businessinsider.es/tecnologia/instagram-ofrece-creadores-contenido-18000-euros-atraer-personas-1462193',
#   'article_keywords': ['Instagram',
#    'creadores de contenido',
#    'programa Referrals',
#    'registro'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107509941',
#   'article_title': 'Brian Chesky (Airbnb) cree que hay un "lado positivo" en montar negocios en una economía inestable',
#   'article_url': 'https://www.businessinsider.es/tecnologia/brian-chesky-airbnb-cree-hay-lado-positivo-montar-negocios-economia-inestable-1462988',
#   'article_keywords': ['Airbnb',
#    'Brian Chesky',
#    'negocios',
#    'economía inestable'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107520096',
#   'article_title': 'MF Talent premia el talento y la innovación e impulsa la IA y la ciberseguridad como motores de un futuro más sostenible',
#   'article_url': 'https://www.businessinsider.es/tecnologia/mf-talent-premia-talento-innovacion-impulsa-ia-ciberseguridad-como-motores-futuro-sostenible-1462985',
#   'article_keywords': ['MF Talent', 'talento', 'innovación', 'IA'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107530259',
#   'article_title': 'Xiaomi lanza su segundo coche eléctrico: su YU7 es la nueva amenaza para Tesla en China',
#   'article_url': 'https://www.businessinsider.es/tecnologia/xiaomi-lanza-segundo-coche-electrico-yu7-nueva-amenaza-tesla-china-1462987',
#   'article_keywords': ['Xiaomi', 'coche eléctrico', 'amulet', 'Tesla'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107540429',
#   'article_title': 'Cook ignora a Trump: Apple ampliará su cadena de suministro en India con una planta de 1.300 millones de euros',
#   'article_url': 'https://www.businessinsider.es/tecnologia/cook-ignora-trump-apple-ampliara-cadena-suministro-india-planta-1300-millones-euros-1462924',
#   'article_keywords': ['Apple', 'Tim Cook', 'India', 'cadena de suministro'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107550653',
#   'article_title': 'Esta es la verdadera razón por la que OpenAI se gasta 5.750 millones de euros en hacerse con la startup de IA de Jony Ive',
#   'article_url': 'https://www.businessinsider.es/tecnologia/verdadera-razon-openai-gasta-5750-millones-euros-hacerse-startup-ia-jony-ive-1462758',
#   'article_keywords': ['OpenAI', 'Jony Ive', 'IA', 'startup'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107560942',
#   'article_title': 'OpenAI compra una startup de hardware de IA al diseñador del iPhone por casi 5.750 millones euros',
#   'article_url': 'https://www.businessinsider.es/tecnologia/openai-compra-startup-hardware-ia-disenador-iphone-casi-5750-millones-euros-1462702',
#   'article_keywords': ['OpenAI', 'hardware de IA', 'Jony Ive', 'compra'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107571256',
#   'article_title': 'Hacienda te llama solo desde este número de teléfono, el resto son estafas',
#   'article_url': 'https://www.businessinsider.es/tecnologia/hacienda-te-llama-solo-numero-telefono-resto-son-estafas-1462719',
#   'article_keywords': ['Hacienda', 'teléfono', 'estafas', 'seguridad'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'},
#  {'model': 'gpt-4o-2024-11-20',
#   'run_id': 'RUNID_1',
#   'task_name': 'source_parsing_v0',
#   'source_name': 'business_insider',
#   'article_id': 'business_insider--20250529174107581539',
#   'article_title': 'Sergey Brin (Google) explica por qué ha vuelto a la empresa para trabajar en IA "prácticamente todos los días"',
#   'article_url': 'https://www.businessinsider.es/tecnologia/sergey-brin-google-explica-ha-vuelto-empresa-trabajar-ia-practicamente-todos-dias-1462584',
#   'article_keywords': ['Sergey Brin', 'Google', 'IA', 'trabajo'],
#   'article_language': 'es',
#   'crawled_at': '2025-05-29 17:16:04'}]

# %%
with open(os.path.join(OUTPUT_DATA_PATH, f"raw_articles_list_{RUNID}.json"), 'w') as f:
    json.dump(new_raw_articles_list, f, indent=4)
print(f"New raw articles list saved to {OUTPUT_DATA_PATH}raw_articles_list_{RUNID}.json")
# Out:
# New raw articles list saved to ../local_tests_data/raw_articles_list/RUNID_1/raw_articles_list_RUNID_1.json
