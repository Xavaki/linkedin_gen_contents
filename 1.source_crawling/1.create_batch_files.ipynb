# %%
from azure.storage.blob import BlobServiceClient
import json
from math import ceil
from datetime import datetime
import os

# %%
TASK_NAME = "source_parsing_v0"
DEPLOYMENT_NAME = "gpt-4o--batch-2"

# %%
INPUT_DATA_PATH = f"../local_tests_data/source_raw_content/"
run_n = len(os.listdir(INPUT_DATA_PATH))
RUNID = f"RUNID_{run_n}"
INPUT_DATA_PATH = f"../local_tests_data/source_raw_content/{RUNID}/"
RUN_TIME = datetime.strftime(datetime.now(), '%Y-%m-%d %H:%M:%S')

OUTPUT_DATA_PATH = f"../local_tests_data/azure_openai_batch_processing_files/{RUNID}/{TASK_NAME}/BATCHFILES/"

os.makedirs(OUTPUT_DATA_PATH, exist_ok=True)

print(f"Run ID: {RUNID} at {RUN_TIME}")
# Out:
# Run ID: RUNID_1 at 2025-05-29 16:18:03

# %%
def get_source_raw_contents():
    source_raw_contents = []
    for file in os.listdir(INPUT_DATA_PATH):
        if file.endswith(".json"):
            with open(os.path.join(INPUT_DATA_PATH, file), 'r') as f:
                data = json.load(f)
                source_raw_contents.append(data)
    return source_raw_contents

# %%
source_raw_contents = get_source_raw_contents()

# %%
source_raw_contents
# Out:
# [{'url': 'https://thenextweb.com/',
#   'name': 'the_next_web',
#   'raw_jina_content': 'Title: TNW | The heart of tech\n\nURL Source: https://thenextweb.com/\n\nMarkdown Content:\nTNW | The heart of tech\n\n===============\n[Skip to content](https://thenextweb.com/#main)\n\nToggle Navigation\n\n[](https://thenextweb.com/)\n\n*   [News](https://thenextweb.com/)\n*   Events\n    *   [TNW Conference June 19 & 20, 2025](https://thenextweb.com/conference)\n    *   [All events](https://thenextweb.com/events)\n\n*   [Spaces](https://thenextweb.com/spaces)\n*   [Programs](https://thenextweb.com/programs)\n\n* * *\n\n*   [Newsletters](https://thenextweb.com/newsletters)\n*   [Partner with us](https://thenextweb.com/partnerships)\n\n*   [](https://facebook.com/thenextweb)\n*   [](https://www.instagram.com/thenextweb)\n*   [](https://twitter.com/thenextweb)\n*   [](https://youtube.com/user/thenextweb)\n*   [](https://flipboard.com/@thenextweb)\n*   [](https://thenextweb.com/newsletters)\n\n*   [Jobs](https://thenextweb.homerun.co/)\n*   [Contact](mailto:conference@thenextweb.com)\n\n[](https://thenextweb.com/)News[news news news](https://thenextweb.com/)\n\n*   [Latest](https://thenextweb.com/latest)\n*   [Deep tech](https://thenextweb.com/deep-tech)\n*   [Sustainability](https://thenextweb.com/sustainability)\n*   [Ecosystems](https://thenextweb.com/ecosystems)\n*   [Data and security](https://thenextweb.com/data-security)\n*   [Fintech and ecommerce](https://thenextweb.com/fintech-ecommerce)\n*   [Future of work](https://thenextweb.com/future-of-work)\n*   [Conference media hub](https://thenextweb.com/topic/tnw-conference)\n*   More\n    *   [Startups and technology](https://thenextweb.com/startups-technology)\n    *   [Investors and funding](https://thenextweb.com/investors-funding)\n    *   [Government and policy](https://thenextweb.com/government-policy)\n    *   [Corporates and innovation](https://thenextweb.com/corporates-innovation)\n    *   [Podcast](https://fast.wistia.com/embed/channel/hckmzyzq7e)\
#   'crawl_time': '2025-05-29 12:38:03'},
#  {'url': 'https://www.itespresso.es/',
#   'name': 'itespresso',
#   'raw_jina_content': 'Title: ITespresso.es\n\nURL Source: https://www.itespresso.es/\n\nMarkdown Content:\nITespresso.es - La actualidad de las Nuevas Tecnologías al instante\n\n===============\n\nContinuar sin aceptar →\n\nCon tu consentimiento, nosotros y [nuestros 918 socios](javascript:Didomi.preferences.show(\'vendors\')) usamos cookies o tecnologías similares para almacenar, acceder y procesar datos personales, como tus visitas a esta página web, las direcciones IP y los identificadores de cookies. Algunos socios no te piden consentimiento para procesar tus datos y se amparan en su legítimo interés comercial. Puedes retirar tu consentimiento u oponerte al procesamiento de datos según el interés legítimo en cualquier momento haciendo clic en \'\'Obtener más información\'\' o en la política de privacidad de esta página web.\n\nNosotros y nuestros socios hacemos el siguiente tratamiento de datos:Almacenar la información en un dispositivo y/o acceder a ella, Datos de localización geográfica precisa e identificación mediante análisis de dispositivos, Publicidad y contenido personalizados, medición de publicidad y contenido, investigación de audiencia y desarrollo de servicios\n\nMás información →Aceptar y cerrar\n\n[ITespresso.es](https://www.itespresso.es/ "ITespresso.es")\nLa actualidad de las Nuevas Tecnologías al instante\n===================================================\n\n*   [Síganos](https://www.itespresso.es/#)\n    *   [Facebook](https://www.facebook.com/ITespresso.es/)\n    *   [X](http://twitter.com/ITespresso)\n    *   [RSS](http://feeds.itespresso.es/itespresso/actualidad)\n\n*   [Newsletter](https://subscriber.itespresso.es/profile/new-profile-1.php?continue=http%3A%2F%2Fwww.itespresso.es%2F&continue_label=ITespresso.es&utm_source=kamino-newsletter-top)\n*   [Login](https://subscriber.itespresso.es/profile/login.php?continue=http%3A%2F%2Fwww.itespresso.es%2F&continue_label=ITespresso.es)\n\nBuscar:  \n\n*   [Menu](https://www.itespresso.es/#)\n    *   [Categorías](https://www.itespresso.es/#)\n        *   [Cloud](https://www.itespresso.es/actualidad/cloud)\n            *   [Datacenter](https://www.itespresso.es/actualidad/cloud/datacenter)\n            *   [Gestión Cloud](https://www.itespresso.es/actualidad/cloud/cloud-management)\n            *   [IaaS](https://www.itespresso.es/actualidad/cloud/iaas)\n            *   [PaaS](https://www.itespresso.es/actualidad/cloud/paas)\n            *   [SaaS](https://www.itespresso.es/actualidad/cloud/saas)\n            *   [Servidores](https://www.itespresso.es/actualidad/cloud/server)\n            *   [Virtualización](https://www.itespresso.es/actualidad/cloud/virtualization)\n\n        *   [Empresas](https://www.itespresso.es/actualidad/e-enterprise)\n            *   [Adquisiciones y Fusiones](https://www.itespresso.es/actualidad/e-enterprise/merger-acquisition)\n            *   [Financiación](https://www.itespresso.es/actualidad/e-enterprise/fund-raising)\n            *   [Mercados financieros](https://www.itespresso.es/actualidad/e-enterprise/financial-market)\n            *   [Startups](https://www.itespresso.es/actualidad/e-enterprise/start-up)\n\n        *   [Gestión empresarial](https://www.itespresso.es/actualidad/e-management)\n            *   [Despidos](https://www.itespresso.es/actualidad/e-management/social-laws)\n            *   [Nombramientos](https://www.itespresso.es/actualidad/e-management/nominations)\n\n        *   [Innovación](https://www.itespresso.es/actualidad/e-innovation)\n            *   [Ciencia](https://www.itespresso.es/actualidad/e-innovation/science)\n            *   [Green IT](https://www.itespresso.es/actualidad/e-innovation/green-it)\n            *   [Investigación](https://www.itespresso.es/actualidad/e-innovation/research)\n            *   [Wearables](https://www.itespresso.es/actualidad/e-innovation/wearable)\n\n        *   [Marketing](https://www.itespresso.es/actualidad/e-marketing)\n            *   [CRM](https://www.itespresso ...
#   'crawl_time': '2025-05-29 12:38:03'}]

# %%
prompts_per_batch_job = 200
n_to_process = len(source_raw_contents)
n_batch_jobs = ceil(n_to_process/prompts_per_batch_job)
print("Creating {} batch files".format(n_batch_jobs))
# Out:
# Creating 1 batch files

# %%
system_prompt = """
Extract an article list from the following page content. Do not make up any information that's not in the provided text. If the provided content text contains no articles list (for instance due to a 'page not found' error), return an empty list.

You must adhere to the provided criteria and schema.
"""

# %%
def format_task_jsonl_line(task_id, deployment_name, user_input):
    jsonl_line_template = {
        "custom_id": task_id,
        "method": "POST",
        "url": "/chat/completions",
        "body": {
            "model": deployment_name,
            "messages": [
                {
                    "role": "system",
                    "content": system_prompt.replace("\n", "\\n")
                },
                {
                    "role": "user",
                    "content": user_input.replace("\n", "\\n")
                }
            ],
            "response_format": {
            "type": "json_schema",
            "json_schema": {
                "name": "ArticleLinksList",
                "strict": True,
                "schema": {
                    "type": "object",
                    "properties": {
                        "article_links_list": {
                            "type": "array",
                            "items" : {"$ref": "#/$defs/article_link"}
                        },
                    },
                    "$defs": {
                        "article_link" : {
                            "type" : "object",
                            "properties" : {
                                "title" : {
                                    "type": "string"
                                },
                                "url" : {
                                    "type": "string",
                                },
                                "keywords" : {
                                    "type": "array",
                                    "items": {
                                        "type": "string"
                                    }
                                },
                                "language": {
                                    "type": "string",
                                },
                            },
                            "required": [
                                "title",
                                "url",
                                "keywords",
                                "language"
                            ],
                            "additionalProperties": False
                        }
                    },
                    "required": [
                        "article_links_list",
                    ],
                    "additionalProperties": False
                }
            }
        }
        }
    }
    return jsonl_line_template

# %%
def generate_jsonl_lines(chunk_id, chunk_sources):
    for j,source_info in enumerate(chunk_sources):
        source_name = source_info['name'] 
        raw_jina_content = source_info['raw_jina_content']
        task_id = f"{RUNID}--{TASK_NAME}--{source_name}"
        deployment_name = DEPLOYMENT_NAME
        yield json.dumps(format_task_jsonl_line(task_id=task_id, deployment_name=deployment_name, user_input=raw_jina_content)) + "\n"

# %%
for i in range(n_batch_jobs):
    print(i)
    chunk = source_raw_contents[i*prompts_per_batch_job:min(n_to_process, (i+1)*prompts_per_batch_job)]
    batchfilename = f"{RUNID}--{TASK_NAME}_BATCHFILE_{i}.jsonl"

    with open(OUTPUT_DATA_PATH + batchfilename, "w") as f:
        for line in generate_jsonl_lines(chunk_id=i, chunk_sources=chunk):
            f.write(line)
# Out:
# 0
